# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
#Configuration
sequence_length = 5
batch_size = 64
epochs = 100

input_features = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z', 'Tilt_X', 'Tilt_Y', 'Tilt_Z', 'Mag_X', 'Mag_Y', 'Mag_Z', 'Head', 'Temp', 'Press', 'delta_Alt']
#input_features = ['Acc_X', 'Acc_Y', 'Gyro_X', 'Gyro_Y', 'Gyro_Z', 'Head']
target_features = ['delta_Lng', 'delta_Lat']

train_folder = 'data/train'
test_folder = 'data/test'
models_folder = 'models'

# %%
# Load and preprocess data from all CSV files in the 'train' folder
def load_data_from_folder(folder_path):
    sequences = []
    targets = []
    
    for file in os.listdir(folder_path):
        if file.endswith('.csv'):
            # Load the CSV file
            file_path = os.path.join(folder_path, file)
            data = pd.read_csv(file_path, delimiter=";")
            
            if len(data) < sequence_length:
                # Skip files with fewer rows than the sequence length
                continue
            
            # Normalize the input data (sensor data)
            input_data = data[input_features].values
            
            # Target data (deltas)
            target_data = data[target_features].values * 1000
            
            # Create sequences of input data and corresponding target deltas
            for i in range(len(data) - sequence_length):
                sequences.append(input_data[i:i + sequence_length])
                targets.append(target_data[i + sequence_length])

    return np.array(sequences), np.array(targets)

# %%
# Load data
X_train, y_train = load_data_from_folder(train_folder)
X_test, y_test = load_data_from_folder(test_folder)

# %%
def plot_training_histories(*args, figsize=(15, 10)):
    colors = ['red', 'green', 'blue', 'purple', 'orange']
    metrics = ['accuracy', 'loss', 'val_accuracy', 'val_loss']
    titles = ['Training Accuracy', 'Training Loss', 'Validation Accuracy', 'Validation Loss']
    
    plt.figure(figsize=figsize)
    
    for i, metric in enumerate(metrics):
        plt.subplot(4, 1, i+1)
        for j, (history, label) in enumerate(args):
            color = colors[j % len(colors)]
            plt.plot(history.history[metric], label=f'{label} ({metric})', color=color)
        plt.title(titles[i])
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy' if 'accuracy' in metric else 'Loss')
        plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(sequence_length, len(input_features)), return_sequences=False))
model.add(Dense(64, activation='leaky_relu'))
model.add(Dense(64, activation='leaky_relu'))
model.add(Dense(2))  # Output: deltaLat, deltaLng, deltaAltGPS

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size)  

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")

# Save the trained model
model_name = f'lstm_delta_gps_model_{sequence_length}seq_{epochs}epochs.keras'
model.save(os.path.join(models_folder, model_name))
# Out:
# Epoch 1/100
# c:\Users\Usuario\anaconda3\envs\Quanvia\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5307 - loss: 0.0142 - val_accuracy: 0.5977 - val_loss: 0.0060
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7069 - loss: 0.0081 - val_accuracy: 0.7184 - val_loss: 0.0045
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7928 - loss: 0.0069 - val_accuracy: 0.6839 - val_loss: 0.0045
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8055 - loss: 0.0067 - val_accuracy: 0.7644 - val_loss: 0.0037
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8381 - loss: 0.0054 - val_accuracy: 0.4368 - val_loss: 0.0211
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6790 - loss: 0.0119 - val_accuracy: 0.7414 - val_loss: 0.0042
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8161 - loss: 0.0066 - val_accuracy: 0.7989 - val_loss: 0.0035
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8852 - loss: 0.0050 - val_accuracy: 0.8161 - val_loss: 0.0033
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8617 - loss: 0.0047 - val_accuracy: 0.6839 - val_loss: 0.0054
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7142 - loss: 0.0077 - val_accuracy: 0.8103 - val_loss: 0.0037
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8941 - loss: 0.0044 - val_accuracy: 0.7299 - val_loss: 0.0046
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8599 - loss: 0.0066 - val_accuracy: 0.7989 - val_loss: 0.0036
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8944 - loss: 0.0050 - val_accuracy: 0.8333 - val_loss: 0.0035
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8692 - loss: 0.0043 - val_accuracy: 0.6897 - val_loss: 0.0062
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8493 - loss: 0.0063 - val_accuracy: 0.8218 - val_loss: 0.0030
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8937 - loss: 0.0047 - val_accuracy: 0.8218 - val_loss: 0.0034
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9045 - loss: 0.0050 - val_accuracy: 0.8391 - val_loss: 0.0032
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9187 - loss: 0.0037 - val_accuracy: 0.8448 - val_loss: 0.0032
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9210 - loss: 0.0039 - val_accuracy: 0.8333 - val_loss: 0.0029
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9148 - loss: 0.0043 - val_accuracy: 0.7931 - val_loss: 0.0035
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9243 - loss: 0.0035 - val_accuracy: 0.8448 - val_loss: 0.0028
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9204 - loss: 0.0037 - val_accuracy: 0.8621 - val_loss: 0.0031
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9177 - loss: 0.0039 - val_accuracy: 0.7701 - val_loss: 0.0048
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8723 - loss: 0.0049 - val_accuracy: 0.7586 - val_loss: 0.0040
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9238 - loss: 0.0037 - val_accuracy: 0.7816 - val_loss: 0.0036
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9243 - loss: 0.0038 - val_accuracy: 0.8218 - val_loss: 0.0028
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9146 - loss: 0.0034 - val_accuracy: 0.8736 - val_loss: 0.0027
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9179 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 0.0031
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9109 - loss: 0.0034 - val_accuracy: 0.8678 - val_loss: 0.0031
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9269 - loss: 0.0041 - val_accuracy: 0.8448 - val_loss: 0.0026
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9407 - loss: 0.0034 - val_accuracy: 0.8218 - val_loss: 0.0029
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9206 - loss: 0.0036 - val_accuracy: 0.8851 - val_loss: 0.0031
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9327 - loss: 0.0033 - val_accuracy: 0.7126 - val_loss: 0.0071
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8733 - loss: 0.0054 - val_accuracy: 0.8621 - val_loss: 0.0027
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9128 - loss: 0.0033 - val_accuracy: 0.8563 - val_loss: 0.0034
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9095 - loss: 0.0035 - val_accuracy: 0.8793 - val_loss: 0.0027
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9160 - loss: 0.0030 - val_accuracy: 0.8908 - val_loss: 0.0026
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9183 - loss: 0.0033 - val_accuracy: 0.8793 - val_loss: 0.0027
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9230 - loss: 0.0032 - val_accuracy: 0.8793 - val_loss: 0.0035
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9113 - loss: 0.0039 - val_accuracy: 0.8506 - val_loss: 0.0030
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.0032 - val_accuracy: 0.8793 - val_loss: 0.0025
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9211 - loss: 0.0030 - val_accuracy: 0.8448 - val_loss: 0.0038
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8822 - loss: 0.0043 - val_accuracy: 0.8621 - val_loss: 0.0023
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9168 - loss: 0.0031 - val_accuracy: 0.7471 - val_loss: 0.0048
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9097 - loss: 0.0044 - val_accuracy: 0.8851 - val_loss: 0.0024
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9177 - loss: 0.0032 - val_accuracy: 0.8391 - val_loss: 0.0026
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9374 - loss: 0.0032 - val_accuracy: 0.8851 - val_loss: 0.0034
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9184 - loss: 0.0043 - val_accuracy: 0.8276 - val_loss: 0.0030
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9115 - loss: 0.0038 - val_accuracy: 0.9138 - val_loss: 0.0024
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9213 - loss: 0.0035 - val_accuracy: 0.8046 - val_loss: 0.0029
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9160 - loss: 0.0033 - val_accuracy: 0.8276 - val_loss: 0.0032
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9273 - loss: 0.0029 - val_accuracy: 0.8563 - val_loss: 0.0027
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.0029 - val_accuracy: 0.7816 - val_loss: 0.0035
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9344 - loss: 0.0031 - val_accuracy: 0.7874 - val_loss: 0.0038
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9231 - loss: 0.0031 - val_accuracy: 0.8333 - val_loss: 0.0029
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9254 - loss: 0.0032 - val_accuracy: 0.7586 - val_loss: 0.0039
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.0031 - val_accuracy: 0.8908 - val_loss: 0.0022
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9229 - loss: 0.0030 - val_accuracy: 0.8103 - val_loss: 0.0030
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9268 - loss: 0.0029 - val_accuracy: 0.8563 - val_loss: 0.0025
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9376 - loss: 0.0030 - val_accuracy: 0.7931 - val_loss: 0.0028
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.0028 - val_accuracy: 0.7989 - val_loss: 0.0038
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9279 - loss: 0.0033 - val_accuracy: 0.8103 - val_loss: 0.0029
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9271 - loss: 0.0029 - val_accuracy: 0.9023 - val_loss: 0.0021
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9273 - loss: 0.0029 - val_accuracy: 0.8391 - val_loss: 0.0030
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9260 - loss: 0.0031 - val_accuracy: 0.8103 - val_loss: 0.0029
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9253 - loss: 0.0027 - val_accuracy: 0.7759 - val_loss: 0.0035
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9214 - loss: 0.0029 - val_accuracy: 0.6034 - val_loss: 0.0075
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7536 - loss: 0.0072 - val_accuracy: 0.8333 - val_loss: 0.0031
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8858 - loss: 0.0039 - val_accuracy: 0.8046 - val_loss: 0.0036
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8936 - loss: 0.0037 - val_accuracy: 0.8103 - val_loss: 0.0027
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8911 - loss: 0.0043 - val_accuracy: 0.8506 - val_loss: 0.0025
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9088 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 0.0025
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9161 - loss: 0.0035 - val_accuracy: 0.8621 - val_loss: 0.0027
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8936 - loss: 0.0056 - val_accuracy: 0.7011 - val_loss: 0.0059
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8704 - loss: 0.0052 - val_accuracy: 0.8448 - val_loss: 0.0025
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9150 - loss: 0.0038 - val_accuracy: 0.8448 - val_loss: 0.0025
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.0034 - val_accuracy: 0.7701 - val_loss: 0.0039
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8799 - loss: 0.0044 - val_accuracy: 0.8448 - val_loss: 0.0027
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9056 - loss: 0.0036 - val_accuracy: 0.8506 - val_loss: 0.0035
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8886 - loss: 0.0039 - val_accuracy: 0.8046 - val_loss: 0.0029
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9145 - loss: 0.0033 - val_accuracy: 0.8621 - val_loss: 0.0025
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9293 - loss: 0.0029 - val_accuracy: 0.8851 - val_loss: 0.0022
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9128 - loss: 0.0033 - val_accuracy: 0.8506 - val_loss: 0.0022
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9220 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 0.0025
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9211 - loss: 0.0027 - val_accuracy: 0.8966 - val_loss: 0.0027
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9221 - loss: 0.0034 - val_accuracy: 0.7701 - val_loss: 0.0038
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9161 - loss: 0.0032 - val_accuracy: 0.8103 - val_loss: 0.0035
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9195 - loss: 0.0040 - val_accuracy: 0.8161 - val_loss: 0.0065
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8373 - loss: 0.0060 - val_accuracy: 0.8908 - val_loss: 0.0021
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9099 - loss: 0.0033 - val_accuracy: 0.8563 - val_loss: 0.0023
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.0029 - val_accuracy: 0.8563 - val_loss: 0.0024
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9148 - loss: 0.0027 - val_accuracy: 0.8908 - val_loss: 0.0025
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9250 - loss: 0.0028 - val_accuracy: 0.8563 - val_loss: 0.0025
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8604 - loss: 0.0046 - val_accuracy: 0.8621 - val_loss: 0.0025
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9214 - loss: 0.0030 - val_accuracy: 0.8678 - val_loss: 0.0026
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9113 - loss: 0.0044 - val_accuracy: 0.8851 - val_loss: 0.0025
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9152 - loss: 0.0035 - val_accuracy: 0.8276 - val_loss: 0.0025
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9213 - loss: 0.0032 - val_accuracy: 0.8793 - val_loss: 0.0024
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9240 - loss: 0.0032 - val_accuracy: 0.8793 - val_loss: 0.0024
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.0032 - val_accuracy: 0.8276 - val_loss: 0.0029
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9143 - loss: 0.0021
# Test Loss: [0.0029004456009715796, 0.8275862336158752]

# %%
plot_training_histories((history, 'LSTM'))

# %%
def plot_test_data(folder_path, model):
    sequences = []
    targets = []
    
    for file in os.listdir(folder_path):
        # Load the CSV file
        file_path = os.path.join(folder_path, file)
        data = pd.read_csv(file_path, delimiter=";")
        
        if len(data) < sequence_length:
            # Skip files with fewer rows than the sequence length
            continue
        
        # Normalize the input data (sensor data)
        input_data = data[input_features].values
        
        # Target data (deltas)
        target_data = data[target_features].values * 1000
        
        # Create sequences of input data and corresponding target deltas
        for i in range(len(data) - sequence_length):
            sequences.append(input_data[i:i + sequence_length])
            targets.append(target_data[i + sequence_length])
        
        model.layers[0].reset_states()

        y_pred = model.predict(np.array(sequences))
        y_test = np.array(targets)

        # Plot the predicted and true values
        fig, axs = plt.subplots(2, 2, figsize=(25, 20))
        
        # Plot actual vs predicted for delta_Lat
        axs[0, 0].plot(y_test[:, 0], label='Actual delta_Lng', color='blue')
        axs[0, 0].plot(y_pred[:, 0], label='Predicted delta_Lng', color='red')
        axs[0, 0].set_title('Actual vs Predicted delta_Lng')
        axs[0, 0].legend()

        # Plot actual vs predicted for delta_Lng
        axs[0, 1].plot(y_test[:, 1], label='Actual delta_Lat', color='blue')
        axs[0, 1].plot(y_pred[:, 1], label='Predicted delta_Lat', color='red')
        axs[0, 1].set_title('Actual vs Predicted delta_Lat')
        axs[0, 1].legend()

        #Scatter
        # Plot actual vs predicted for deltaY as scatter plot
        axs[1, 0].scatter(range(len(y_test[:, 0])), y_test[:, 0], label='Actual delta_Lng', color='blue')
        axs[1, 0].scatter(range(len(y_pred[:, 0])), y_pred[:, 0], label='Predicted delta_Lng', color='red')
        axs[1, 0].set_title('Actual vs Predicted delta_Lng')
        axs[1, 0].legend()

        axs[1, 1].scatter(range(len(y_test[:, 1])), y_test[:, 1], label='Actual delta_Lat', color='blue')
        axs[1, 1].scatter(range(len(y_pred[:, 1])), y_pred[:, 1], label='Predicted delta_Lat', color='red')
        axs[1, 1].set_title('Actual vs Predicted delta_Lat')
        axs[1, 1].legend()

        # Adjust layout
        fig.suptitle('Test file: ' + file, fontsize=16)
        plt.tight_layout()
        plt.show()

# %%
#plot_test_data(test_folder, model)

# %%
# Function to calculate real and predicted routes
def calculate_routes(file_path, sequence_length, input_features, model, verbose):
    data = pd.read_csv(file_path, delimiter=";")
    
    # Get the first point from 'Lat' and 'Lng'
    
    lng_real = [data.iloc[0]['Lng']]
    lat_real = [data.iloc[0]['Lat']]

    # Initialize real route
    for i in range(1, len(data)):
        # Get the deltas
        delta_lng = data.iloc[i]['delta_Lng']
        delta_lat = data.iloc[i]['delta_Lat']

        # Calculate next point based on the previous one
        lng_real.append(lng_real[-1] + delta_lng)
        lat_real.append(lat_real[-1] + delta_lat)
    
    # Now calculate the predicted route
    lng_pred = [data.iloc[0]['Lng']]
    lat_pred = [data.iloc[0]['Lat']]
    
    # Extract input data
    input_data = data[input_features].values
    print("\n\n")
    # Predict deltas and accumulate to form the predicted route
    for i in range(1, len(data)):
        # Prepare sequence for prediction
        if i >= sequence_length:
            X_test = input_data[i-sequence_length:i].reshape(1, sequence_length, len(input_features))
            delta_lng_pred, delta_lat_pred = model.predict(X_test, verbose=verbose)[0] / 1000

            #print(f"Predicted deltas: {delta_lng_pred*1000}, {delta_lat_pred*1000}")
            #print(f"Real deltas: {data.iloc[i]['delta_Lng']*1000}, {data.iloc[i]['delta_Lat']*1000}")

            lng_pred.append(lng_pred[-1] + delta_lng_pred)
            lat_pred.append(lat_pred[-1] + delta_lat_pred)

        else:
            # For first few rows, just use the real data
            lng_pred.append(lng_real[i])
            lat_pred.append(lat_real[i])

    
    return lng_real, lat_real, lng_pred, lat_pred

# Function to plot real and predicted routes for each test file
def plot_routes(test_folder, sequence_length, input_features, model, verbose):
    test_files = [f for f in os.listdir(test_folder) if f.endswith('.csv')]
    num_files = len(test_files)
    
    fig, axes = plt.subplots(nrows=num_files, ncols=1, figsize=(8, num_files * 6))
    
    if num_files == 1:
        axes = [axes]  #Ensure axes is iterable if there's only one file
    
    for idx, test_file in enumerate(test_files):
        file_path = os.path.join(test_folder, test_file)

        model.layers[0].reset_states()
        
        lng_real, lat_real, lng_pred, lat_pred = calculate_routes(file_path, sequence_length, input_features, model, verbose)
        
        # Plot real and predicted points
        axes[idx].plot(lng_real, lat_real, color='blue', label='Real Route', marker='o', markersize=5)
        axes[idx].plot(lng_pred, lat_pred, color='red', label='Predicted Route', marker='o', markersize=5)
        
        axes[idx].set_title(f'Test File: {test_file}')
        axes[idx].set_xlabel('Lng')
        axes[idx].set_ylabel('Lat')
        axes[idx].legend()
    
    # Adjust layout
    plt.tight_layout()
    plt.show()

# %%
sequence_length = 5
verbose = 0 # Set to 1 to print more information about the training process
plot_routes(train_folder, sequence_length, input_features, model, verbose)
